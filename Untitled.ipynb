# %%
import requests
import pandas as pd
import numpy as np

# %%
filepath = 'Final_DataFrame.csv'
df = pd.read_csv(filepath)

# %%
df
# Out:
#       Unnamed: 0                  Address    City  Zip Code   Price    sqft  \
# 0              0        7947 Claremont DR  Dallas   75228.0  317900     NaN
# 1              1       9833 Walnut Street  Dallas   75243.0   50000     NaN
# 2              2       9825 Walnut Street  Dallas   75243.0   50000     NaN
# 3              3       9809 Walnut Street  Dallas   75243.0   50000     NaN
# 4              4       9805 Walnut Street  Dallas   75243.0   51000     NaN
# ...          ...                      ...     ...       ...     ...     ...
# 3104        3230      5111 Stillwater Trl  Frisco   75034.0  925000  4061.0
# 3105        3231         1403 Crockett Dr  Frisco   75033.0  625000  3757.0
# 3106        3232  12144 Cardinal Creek Dr  Frisco   75033.0  329000  1805.0
# 3107        3233   949 Imperial Valley Ln  Frisco   75036.0  430000  1786.0
# 3108        3234          2260 Lariat Trl  Frisco   75036.0  350000  1841.0
#
#       # of Beds  # of Baths
# ...

# %%
df_address = df['Address']
set(df_address.tolist())
# Out:
# 3235

# %%
# Out:
#       Unnamed: 0                  Address    City  Zip Code   Price    sqft  \
# 0              0        7947 Claremont DR  Dallas   75228.0  317900     NaN
# 1              1       9833 Walnut Street  Dallas   75243.0   50000     NaN
# 2              2       9825 Walnut Street  Dallas   75243.0   50000     NaN
# 3              3       9809 Walnut Street  Dallas   75243.0   50000     NaN
# 4              4       9805 Walnut Street  Dallas   75243.0   51000     NaN
# ...          ...                      ...     ...       ...     ...     ...
# 3230        3230      5111 Stillwater Trl  Frisco   75034.0  925000  4061.0
# 3231        3231         1403 Crockett Dr  Frisco   75033.0  625000  3757.0
# 3232        3232  12144 Cardinal Creek Dr  Frisco   75033.0  329000  1805.0
# 3233        3233   949 Imperial Valley Ln  Frisco   75036.0  430000  1786.0
# 3234        3234          2260 Lariat Trl  Frisco   75036.0  350000  1841.0
#
#       # of Beds  # of Baths
# ...

# %%
df.loc[df['Address'] == '9833 Walnut Street']
# Out:
#    Unnamed: 0             Address    City  Zip Code  Price  sqft  # of Beds  \
# 1           1  9833 Walnut Street  Dallas   75243.0  50000   NaN        1.0
# 6           6  9833 Walnut Street  Dallas   75243.0  70000   NaN        1.0
#
#    # of Baths
# 1         1.0
# 6         2.0
