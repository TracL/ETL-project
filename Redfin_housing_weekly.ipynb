# %%
import pandas as pd
import numpy as np

# %%
# names of files to read from
r_filenameTSV = '../Downloads/redfin_weekly_housing_data.tsv'

# names of files to write to
w_filenameTSV = '../Downloads/redfin_weekly_housing_data.tsv'

# read the data
tsv_read = pd.read_csv(r_filenameTSV, sep='\t')

# print the first 10 records
print(tsv_read.head(10))

# write to files
with open(w_filenameCSV,'w') as write_csv:
    write_csv.write(tsv_read.to_csv(sep=',', index=False))

with open(w_filenameTSV,'w') as write_tsv:
    write_tsv.write(csv_read.to_csv(sep='\t', index=False))
# Out:
#    region_id  region_type_id           region_name region_type period_begin  \
# 0       1695               5  St. Louis County, MO      county   2020-10-19
# 1       1976               5    Niagara County, NY      county   2017-07-10
# 2       1471               5    Lincoln County, MN      county   2017-06-12
# 3       3201               5  Marquette County, WI      county   2019-10-07
# 4        828               5   Dearborn County, IN      county   2018-08-20
# 5       2181               5       Erie County, OH      county   2019-09-23
# 6       1492               5     Ramsey County, MN      county   2019-08-05
# 7        837               5   Franklin County, IN      county   2019-01-28
# 8        828               5   Dearborn County, IN      county   2019-07-15
# 9       1513               5   Watonwan County, MN      county   2018-10-08
#
#    period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 0  2020-10-25  1 weeks             330.0              0.145833
# 1  2017-07-16  1 weeks              52.0              0.019608
# 2  2017-06-18  1 weeks               1.0                   NaN
# 3  2019-10-13  1 weeks               6.0              1.000000
# 4  2018-08-26  1 weeks               8.0              0.333333
# 5  2019-09-29  1 weeks              13.0              0.181818
# 6  2019-08-11  1 weeks             148.0              0.006803
# 7  2019-02-03  1 weeks               1.0                   NaN
# 8  2019-07-21  1 weeks               3.0             -0.500000
# 9  2018-10-14  1 weeks               NaN                   NaN
#
#    average_homes_sold  ...  median_days_on_market_yoy  \
# 0               330.0  ...                      -13.5
# 1                52.0  ...                       -7.5
# 2                 1.0  ...                        NaN
# 3                 6.0  ...                       47.0
# 4                 8.0  ...                      -36.0
# 5                13.0  ...                       34.0
# 6               148.0  ...                       -7.5
# 7                 1.0  ...                        NaN
# 8                 3.0  ...                       -5.0
# 9                 NaN  ...                        NaN
#
#    pending_sales_to_sales_ratio  pending_sales_to_sales_ratio_yoy  \
# 0                           NaN                               NaN
# 1                      0.903846                          0.178356
# 2                           NaN                               NaN
# 3                      0.500000                         -1.166667
# 4                      0.750000                         -0.250000
# 5                      0.384615                         -0.342657
# 6                      0.945946                         -0.060857
# 7                           NaN                               NaN
# 8                      1.000000                         -0.166667
# 9                           NaN                               NaN
#
#    months_of_supply  months_of_supply_yoy  \
# 0          7.242424             -5.007576
# 1         14.711538             -2.288462
# 2         29.000000                   NaN
# 3         24.166667            -30.166667
# 4         15.625000            -10.208333
# 5         14.692308             -3.489510
# 6          9.506757             -0.153107
# 7         36.000000                   NaN
# 8         32.000000             11.666667
# 9               NaN                   NaN
#
#    average_pending_sales_listing_updates  \
# 0                                  456.0
# 1                                   76.0
# 2                                    1.0
# 3                                    5.0
# 4                                    7.0
# 5                                    NaN
# 6                                  288.0
# 7                                    2.0
# 8                                   10.0
# 9                                    NaN
#
#    average_pending_sales_listing_updates_yoy  \
# 0                                   0.263158
# 1                                   0.288136
# 2                                        NaN
# 3                                  -0.375000
# 4                                   0.750000
# 5                                        NaN
# 6                                  -0.003460
# 7                                        NaN
# 8                                   0.250000
# 9                                        NaN
#
#    percent_total_price_drops_of_inventory  \
# 0                                0.075758
# 1                                0.047414
# 2                                     NaN
# 3                                0.028571
# 4                                0.068376
# 5                                     NaN
# 6                                0.088424
# 7                                     NaN
# 8                                0.054348
# 9                                     NaN
#
#    percent_total_price_drops_of_inventory_yoy         last_updated
# 0                                    0.005392  2021-03-10 14:56:17
# 1                                    0.010377  2021-03-10 14:56:17
# 2                                         NaN  2021-03-10 14:56:17
# 3                                    0.002765  2021-03-10 14:56:17
# 4                                    0.033654  2021-03-10 14:56:17
# 5                                         NaN  2021-03-10 14:56:17
# 6                                    0.011563  2021-03-10 14:56:17
# 7                                         NaN  2021-03-10 14:56:17
# 8                                    0.027562  2021-03-10 14:56:17
# 9                                         NaN  2021-03-10 14:56:17
#
# [10 rows x 82 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7f820c6e47ba> in <module>
#      12
#      13 # write to files
# ---> 14 with open(w_filenameCSV,'w') as write_csv:
#      15     write_csv.write(tsv_read.to_csv(sep=',', index=False))
#      16
#
# NameError: name 'w_filenameCSV' is not defined

# %%
print(tsv_read.head())
# Out:
#     region_id  region_type_id               region_name region_type  \
# 0        1695               5      St. Louis County, MO      county
# 1        1976               5        Niagara County, NY      county
# 2        1471               5        Lincoln County, MN      county
# 3        3201               5      Marquette County, WI      county
# 4         828               5       Dearborn County, IN      county
# ..        ...             ...                       ...         ...
# 77       3183               5         Forest County, WI      county
# 78       1656               5        Lincoln County, MO      county
# 79      14740              -2  Bremerton, WA metro area       metro
# 80        300               5          White County, AR      county
# 81       3119               5          Grant County, WV      county
#
#    period_begin  period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 0    2020-10-19  2020-10-25  1 weeks             330.0              0.145833
# 1    2017-07-10  2017-07-16  1 weeks              52.0              0.019608
# 2    2017-06-12  2017-06-18  1 weeks               1.0                   NaN
# 3    2019-10-07  2019-10-13  1 weeks               6.0              1.000000
# 4    2018-08-20  2018-08-26  1 weeks               8.0              0.333333
# ..          ...         ...      ...               ...                   ...
# 77   2017-03-13  2017-03-19  1 weeks               NaN                   NaN
# 78   2019-04-08  2019-04-14  1 weeks              12.0              0.333333
# 79   2018-06-18  2018-06-24  1 weeks             115.0              0.161616
# 80   2019-01-07  2019-01-13  1 weeks              10.0             -0.230769
# 81   2018-12-24  2018-12-30  1 weeks               2.0                   NaN
#
#     average_homes_sold  ...  median_days_on_market_yoy  \
# 0                330.0  ...                      -13.5
# 1                 52.0  ...                       -7.5
# 2                  1.0  ...                        NaN
# 3                  6.0  ...                       47.0
# 4                  8.0  ...                      -36.0
# ..                 ...  ...                        ...
# 77                 NaN  ...                        NaN
# 78                12.0  ...                      -61.0
# 79               115.0  ...                       -2.0
# 80                10.0  ...                        0.0
# 81                 2.0  ...                        NaN
#
#     pending_sales_to_sales_ratio  pending_sales_to_sales_ratio_yoy  \
# 0                            NaN                               NaN
# 1                       0.903846                          0.178356
# 2                            NaN                               NaN
# 3                       0.500000                         -1.166667
# 4                       0.750000                         -0.250000
# ..                           ...                               ...
# 77                           NaN                               NaN
# 78                           NaN                               NaN
# 79                      0.895652                         -0.205358
# 80                      1.000000                          0.153846
# 81                           NaN                               NaN
#
#     months_of_supply  months_of_supply_yoy  \
# 0           7.242424             -5.007576
# 1          14.711538             -2.288462
# 2          29.000000                   NaN
# 3          24.166667            -30.166667
# 4          15.625000            -10.208333
# ..               ...                   ...
# 77               NaN                   NaN
# 78         14.250000             -8.972222
# 79          6.365217             -2.644884
# 80         26.000000              2.230769
# 81         19.500000                   NaN
#
#     average_pending_sales_listing_updates  \
# 0                                   456.0
# 1                                    76.0
# 2                                     1.0
# 3                                     5.0
# 4                                     7.0
# ..                                    ...
# 77                                    NaN
# 78                                   25.0
# 79                                  133.0
# 80                                   13.0
# 81                                    NaN
#
#     average_pending_sales_listing_updates_yoy  \
# 0                                    0.263158
# 1                                    0.288136
# 2                                         NaN
# 3                                   -0.375000
# 4                                    0.750000
# ..                                        ...
# 77                                        NaN
# 78                                  -0.038462
# 79                                  -0.050000
# 80                                  -0.315789
# 81                                        NaN
#
#     percent_total_price_drops_of_inventory  \
# 0                                 0.075758
# 1                                 0.047414
# 2                                      NaN
# 3                                 0.028571
# 4                                 0.068376
# ..                                     ...
# 77                                     NaN
# 78                                0.059603
# 79                                0.067961
# 80                                0.020747
# 81                                     NaN
#
#     percent_total_price_drops_of_inventory_yoy         last_updated
# 0                                     0.005392  2021-03-10 14:56:17
# 1                                     0.010377  2021-03-10 14:56:17
# 2                                          NaN  2021-03-10 14:56:17
# 3                                     0.002765  2021-03-10 14:56:17
# 4                                     0.033654  2021-03-10 14:56:17
# ..                                         ...                  ...
# 77                                         NaN  2021-03-10 14:56:17
# 78                                    0.018994  2021-03-10 14:56:17
# 79                                    0.011825  2021-03-10 14:56:17
# 80                                   -0.003391  2021-03-10 14:56:17
# 81                                         NaN  2021-03-10 14:56:17
#
# [82 rows x 82 columns]
