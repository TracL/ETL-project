# %%
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from splinter import Browser
import pandas as pd

# %% [markdown]
# ### Setting up browser to scrape data using Splinter

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\freak\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in cache

# %% [markdown]
# ### Scraping Current Listed Properties

# %%
# Visit the following URL
url = "https://www.redfin.com/city/30844/TX/Frisco"
browser.visit(url)

# %%
# Using BeautifulSoup to get html.parser
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Price of listed properties
price_list = []
price = soup.find_all('span', class_="homecardV2Price")
price_list = [p.text for p in price]

# %%
print("Number of records in price list", len(price_list))
# Out:
# Number of records in price list 41

# %%
# Numebr of Beds, Baths and Sq. Ft. of listed properties
beds_list = []
baths_list = []
sq_ft_list = []
stats = soup.find_all('div', class_="stats")

for each in stats:
    val = each.text
    if 'Bed' in val:
        beds_list.append(val.strip())
    elif 'Bath' in val:  
        baths_list.append(val.strip())
    elif 'Sq. Ft.' in val:
        sq_ft_list.append(val.strip())

# %%
print("Number of records in beds list", len(beds_list))
print("Number of records in baths list", len(baths_list))
print("Number of records in sq. ft. list", len(sq_ft_list))
# Out:
# Number of records in beds list 41
# Number of records in baths list 41
# Number of records in sq. ft. list 41

# %%
# Zipcode of listed properties
zipcode_list = []
city_list = []
address_list = []

zipcode = soup.find_all('div', class_="link-and-anchor")
zipcode_list =  [z.text[-5:] for z in zipcode]
address_list = [z.text[:z.text.find(',')] for z in zipcode]
city_list = [z.text[z.text.find(',') + 2 : -6] for z in zipcode]

city_list
# Out:
# ['Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX',
#  'Frisco, TX']

# %% [markdown]
# print("Number of records in zipcode list", len(zipcode_list))

# %% [markdown]
# ### Creating a dataframe with sold real estate properties

# %%
df = pd.DataFrame({"Price": price_list, "Address": address_list, "City": city_list, "Zip Code": zipcode_list, "# of Beds": beds_list, "# of Baths": baths_list, "sqft": sq_ft_list})
df
# Out:
#          Price                  Address        City Zip Code # of Beds  \
# 0     $564,900      7200 Neches Pine Dr  Frisco, TX    75036    3 Beds
# 1     $365,000       10045 Bell Rock Rd  Frisco, TX    75035    3 Beds
# 2     $405,000          11017 Aurora Ln  Frisco, TX    75035    3 Beds
# 3     $449,900      9991 Slick Rock Trl  Frisco, TX    75033    4 Beds
# 4     $515,000            8326 Sitka St  Frisco, TX    75035    4 Beds
# 5     $640,000           2079 Alcove Dr  Frisco, TX    75034    4 Beds
# 6     $389,900         2910 Reynolds Ln  Frisco, TX    75033    3 Beds
# 7     $475,000    13714 French Creek Ln  Frisco, TX    75035    3 Beds
# 8     $930,000         4520 Florence Dr  Frisco, TX    75034    3 Beds
# 9     $439,900          7601 Blossom Ln  Frisco, TX    75034    3 Beds
# 10    $295,000          9805 Concord Dr  Frisco, TX    75035    3 Beds
# 11    $900,000           6198 Rachel Dr  Frisco, TX    75034    4 Beds
# 12    $339,999     12018 Chattanooga Dr  Frisco, TX    75035    3 Beds
# 13    $520,000     12571 Peace River Dr  Frisco, TX    75035    5 Beds
# 14    $460,000            9569 Lance Dr  Frisco, TX    75035    4 Beds
# 15    $325,000       7297 Chinquapin Dr  Frisco, TX    75033    4 Beds
# 16    $500,000    7152 Maumee Valley Ct  Frisco, TX    75036    3 Beds
# 17    $325,000          13160 Guerin Dr  Frisco, TX    75035    4 Beds
# 18    $340,000          6848 Regello Dr  Frisco, TX    75034    2 Beds
# 19    $350,000  9758 Golden Fountain Dr  Frisco, TX    75033    4 Beds
# 20    $325,400      11908 Clearpoint Ct  Frisco, TX    75036    4 Beds
# 21    $445,900   12004 Rushing Creek Dr  Frisco, TX    75035    4 Beds
# 22    $375,000       5904 Louisville Dr  Frisco, TX    75035    4 Beds
# 23    $675,000       1567 San Andres Dr  Frisco, TX    75033    5 Beds
# 24    $437,500         2649 Marshall Dr  Frisco, TX    75033    4 Beds
# 25    $475,000       11708 Blackhawk Dr  Frisco, TX    75033    4 Beds
# 26    $679,545           1545 Morris Ln  Frisco, TX    75034    4 Beds
# 27    $499,900            12923 Yale Ct  Frisco, TX    75035    3 Beds
# 28    $774,900     16372 Lorna Doone Ln  Frisco, TX    75033    5 Beds
# 29    $749,000       12858 Palo Duro Dr  Frisco, TX    75033    5 Beds
# 30    $369,000        2450 Thorntree Dr  Frisco, TX    75033    4 Beds
# 31    $425,000            7927 Canal St  Frisco, TX    75034    2 Beds
# 32  $1,150,000   15246 Crystal Beach Ln  Frisco, TX    75035    6 Beds
# 33  $1,152,990       2481 Haft River Rd  Frisco, TX    75034    5 Beds
# 34    $540,000         8260 Fairview Dr  Frisco, TX    75033    3 Beds
# 35  $1,200,000          6006 Connely Dr  Frisco, TX    75034    5 Beds
# 36    $925,000      5111 Stillwater Trl  Frisco, TX    75034    4 Beds
# 37    $625,000         1403 Crockett Dr  Frisco, TX    75033    4 Beds
# 38    $329,000  12144 Cardinal Creek Dr  Frisco, TX    75033    3 Beds
# 39    $430,000   949 Imperial Valley Ln  Frisco, TX    75036    2 Beds
# 40    $350,000          2260 Lariat Trl  Frisco, TX    75036    3 Beds
#
#    # of Baths           sqft
# 0   2.5 Baths  2,997 Sq. Ft.
# 1     2 Baths  2,169 Sq. Ft.
# 2   2.5 Baths  2,166 Sq. Ft.
# 3   2.5 Baths  2,574 Sq. Ft.
# 4   2.5 Baths  2,962 Sq. Ft.
# 5   2.5 Baths  2,695 Sq. Ft.
# 6     2 Baths  2,236 Sq. Ft.
# 7   2.5 Baths  2,373 Sq. Ft.
# 8   3.5 Baths  4,228 Sq. Ft.
# 9   2.5 Baths  2,383 Sq. Ft.
# 10  2.5 Baths  1,396 Sq. Ft.
# 11    4 Baths  4,967 Sq. Ft.
# 12    2 Baths  1,417 Sq. Ft.
# 13    4 Baths  3,691 Sq. Ft.
# 14  2.5 Baths  3,069 Sq. Ft.
# 15    2 Baths  1,995 Sq. Ft.
# 16    2 Baths  2,246 Sq. Ft.
# 17    2 Baths  2,073 Sq. Ft.
# 18  2.5 Baths  1,818 Sq. Ft.
# 19    2 Baths  2,096 Sq. Ft.
# 20    2 Baths  1,852 Sq. Ft.
# 21  3.5 Baths  2,860 Sq. Ft.
# 22    2 Baths  2,027 Sq. Ft.
# 23  3.5 Baths  4,668 Sq. Ft.
# 24  3.5 Baths  2,927 Sq. Ft.
# 25  2.5 Baths  2,860 Sq. Ft.
# 26    3 Baths  3,623 Sq. Ft.
# 27    3 Baths  1,882 Sq. Ft.
# 28  4.5 Baths  4,147 Sq. Ft.
# 29  5.5 Baths  4,710 Sq. Ft.
# 30    3 Baths  2,207 Sq. Ft.
# 31  2.5 Baths  1,706 Sq. Ft.
# 32    5 Baths  4,813 Sq. Ft.
# 33    4 Baths  4,002 Sq. Ft.
# 34  3.5 Baths  2,128 Sq. Ft.
# 35  4.5 Baths  5,253 Sq. Ft.
# 36  4.5 Baths  4,061 Sq. Ft.
# 37  3.5 Baths  3,757 Sq. Ft.
# 38    2 Baths  1,805 Sq. Ft.
# 39    2 Baths  1,786 Sq. Ft.
# 40    2 Baths  1,841 Sq. Ft.

# %%
df.to_csv("Redfin_Scrape.csv")
